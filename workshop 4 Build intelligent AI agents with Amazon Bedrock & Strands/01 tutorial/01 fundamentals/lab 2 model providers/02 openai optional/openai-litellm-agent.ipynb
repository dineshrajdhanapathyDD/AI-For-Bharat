# %% [markdown]
# # Using OpenAI models with Strands Agent
#
# ## Overview
#
# Strands Agents is an SDK that takes a model-driven approach to building and running AI agents in just a few lines of code. Strands supports multiple providers and models hosted anywhere.
#
# [LiteLLM](https://docs.litellm.ai/docs/) is a unified interface for various LLM providers that allows you to interact with models from Amazon, Anthropic, OpenAI, and many others through a single API. The Strands Agent SDK implements a LiteLLM provider, allowing you to run agents against any model LiteLLM supports.
#
# In this example, we will show you how to use `gpt-4.1-mini` model hosted in Microsoft Azure as the underlying model in your Strands Agent. We will use a simple agent use case with a weather and a get time tool.
#
#
# ## Agent Details
# <div style="float: left; margin-right: 20px;">
#
# |Feature             |Description                                        |
# |--------------------|---------------------------------------------------|
# |Feature used        |LiteLLM model                                      |
# |Agent Structure     |Single agent architecture                          |
#
# </div>

# %% [markdown]
# ## Architecture
#
# <div style="text-align:center">
#     <img src="images/architecture.png" width="65%" />
# </div>
#
# ## Key Features
# * **LiteLLM model**: using a model provided via LiteLLM

# %% [markdown]
# ## Setup and prerequisites
#
# ### Prerequisites
# * Python 3.10+
# * Azure Account
# * gpt-4.1-mini access
#
# Let's now install the requirement packages for our Strands Agent

# %%
# installing pre-requisites
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.1.9)
# Requirement already satisfied: aiohttp>=3.12.13 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (3.13.2)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.37.3)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.37.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.21.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.12.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.11.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.26.20)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.49.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (6.10.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: requests>=0.14.0 in /opt/conda/lib/python3.12/site-packages (from aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Collecting litellm<1.73.0,>=1.72.6 (from strands-agents[litellm]->-r requirements.txt (line 3))
#   Downloading litellm-1.72.9-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.12/site-packages (from litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (8.3.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (3.1.6)
# Collecting openai>=1.68.2 (from litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3))
#   Downloading openai-2.13.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dotenv>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (1.2.1)
# Collecting tiktoken>=0.7.0 (from litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3))
#   Downloading tiktoken-0.12.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tokenizers in /opt/conda/lib/python3.12/site-packages (from litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (0.22.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.2->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.28.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.12.13->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.68.2->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (1.9.0)
# Collecting jiter<1,>=0.10.0 (from openai>=1.68.2->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3))
#   Downloading jiter-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai>=1.68.2->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (46.0.3)
# Requirement already satisfied: cffi>=1.14 in /opt/conda/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=0.14.0->aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.12/site-packages (from tiktoken>=0.7.0->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (2025.11.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /opt/conda/lib/python3.12/site-packages (from tokenizers->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (0.36.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (2024.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.73.0,>=1.72.6->strands-agents[litellm]->-r requirements.txt (line 3)) (6.0.3)
# Downloading litellm-1.72.9-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 136.7 MB/s  0:00:00
# Downloading openai-2.13.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 112.0 MB/s  0:00:00
# Downloading jiter-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (361 kB)
# Downloading tiktoken-0.12.0-cp312-cp312-manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 108.5 MB/s  0:00:00
# Installing collected packages: jiter, tiktoken, openai, litellm
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [litellm]m3/4 [litellm]
# Successfully installed jiter-0.12.0 litellm-1.72.9 openai-2.13.0 tiktoken-0.12.0

# %% [markdown]
# ### Importing dependency packages
#
# Now let's import the dependency packages

# %%
import os
from datetime import datetime
from datetime import timezone as tz
from typing import Any
from zoneinfo import ZoneInfo

from strands import Agent, tool
from strands.models.litellm import LiteLLMModel

# %% [markdown]
# ### Setting up Azure keys
#
# Let's now setup the Azure API Keys

# %%
os.environ["AZURE_API_KEY"] = "<YOUR_API_KEY>"
os.environ["AZURE_API_BASE"] = "<YOUR_API_BASE>"
os.environ["AZURE_API_VERSION"] = "<YOUR_API_VERSION>"

# %% [markdown]
# ### Setting up custom tools
#
# Let's now setup two dummy tools to test our agent

# %%
@tool
def current_time(timezone: str = "UTC") -> str:
    if timezone.upper() == "UTC":
        timezone_obj: Any = tz.utc
    else:
        timezone_obj = ZoneInfo(timezone)

    return datetime.now(timezone_obj).isoformat()


@tool
def current_weather(city: str) -> str:
    # Dummy implementation. Please replace with actual weather API call.
    return "sunny"

# %% [markdown]
# ### Defining agent underlying LLM model
#
# Next let's define our agent underlying model using LiteLLM. We will set it to `gpt-4.1-mini`

# %%
model = "azure/gpt-4.1-mini"
litellm_model = LiteLLMModel(
    model_id=model, params={"max_tokens": 32000, "temperature": 0.7}
)

# %% [markdown]
# ### Defining Agent
#
# Now that we have all the required information available, let's define our agent

# %%
system_prompt = "You are a simple agent that can tell the time and the weather"
agent = Agent(
    model=litellm_model,
    system_prompt=system_prompt,
    tools=[current_time, current_weather],
)

# %% [markdown]
# ### Testing agent
#
# Let's now invoke the agent to test it

# %%
results = agent("What time is it in Seattle? And how is the weather?")
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/litellm/main.py:1194, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1158 optional_param_args = {
#    1159     "functions": functions,
#    1160     "function_call": function_call,
#    (...)
#    1192     "allowed_openai_params": kwargs.get("allowed_openai_params"),
#    1193 }
# -> 1194 optional_params = get_optional_params(
#    1195     **optional_param_args, **non_default_params
#    1196 )
#    1197 processed_non_default_params = pre_process_non_default_params(
#    1198     model=model,
#    1199     passed_params=optional_param_args,
#    (...)
#    1204     add_provider_specific_params=True,
#    1205 )
#
# File /opt/conda/lib/python3.12/site-packages/litellm/utils.py:3766, in get_optional_params(model, functions, function_call, temperature, top_p, n, stream, stream_options, stop, max_tokens, max_completion_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, custom_llm_provider, response_format, seed, tools, tool_choice, max_retries, logprobs, top_logprobs, extra_headers, api_version, parallel_tool_calls, drop_params, allowed_openai_params, reasoning_effort, additional_drop_params, messages, thinking, web_search_options, **kwargs)
#    3760         api_version = (
#    3761             api_version
#    3762             or litellm.api_version
#    3763             or get_secret("AZURE_API_VERSION")
#    3764             or litellm.AZURE_DEFAULT_API_VERSION
#    3765         )
# -> 3766         optional_params = litellm.AzureOpenAIConfig().map_openai_params(
#    3767             non_default_params=non_default_params,
#    3768             optional_params=optional_params,
#    3769             model=model,
#    3770             api_version=api_version,  # type: ignore
#    3771             drop_params=(
#    3772                 drop_params
#    3773                 if drop_params is not None and isinstance(drop_params, bool)
#    3774                 else False
#    3775             ),
#    3776         )
#    3777 elif provider_config is not None:
#
# File /opt/conda/lib/python3.12/site-packages/litellm/llms/azure/chat/gpt_transformation.py:165, in AzureOpenAIConfig.map_openai_params(self, non_default_params, optional_params, model, drop_params, api_version)
#     164 api_version_year = api_version_times[0]
# --> 165 api_version_month = api_version_times[1]
#     166 api_version_day = api_version_times[2]
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results = agent("What time is it in Seattle? And how is the weather?")
#
# File /opt/conda/lib/python3.12/site-packages/strands/agent/agent.py:369, in Agent.__call__(self, prompt, **kwargs)
#     367 with ThreadPoolExecutor() as executor:
#     368     future = executor.submit(execute)
# --> 369     return future.result()
#
# File /opt/conda/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /opt/conda/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/conda/lib/python3.12/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File /opt/conda/lib/python3.12/site-packages/opentelemetry/instrumentation/threading/__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File /opt/conda/lib/python3.12/site-packages/strands/agent/agent.py:365, in Agent.__call__.<locals>.execute()
#     364 def execute() -> AgentResult:
# --> 365     return asyncio.run(self.invoke_async(prompt, **kwargs))
#
# File /opt/conda/lib/python3.12/asyncio/runners.py:195, in run(main, debug, loop_factory)
#     191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 195     return runner.run(main)
#
# File /opt/conda/lib/python3.12/asyncio/runners.py:118, in Runner.run(self, coro, context)
#     116 self._interrupt_count = 0
#     117 try:
# --> 118     return self._loop.run_until_complete(task)
#     119 except exceptions.CancelledError:
#     120     if self._interrupt_count > 0:
#
# File /opt/conda/lib/python3.12/asyncio/base_events.py:691, in BaseEventLoop.run_until_complete(self, future)
#     688 if not future.done():
#     689     raise RuntimeError('Event loop stopped before Future completed.')
# --> 691 return future.result()
#
# File /opt/conda/lib/python3.12/site-packages/strands/agent/agent.py:390, in Agent.invoke_async(self, prompt, **kwargs)
#     372 """Process a natural language prompt through the agent's event loop.
#     373
#     374 This method implements the conversational interface (e.g., `agent("hello!")`). It adds the user's prompt to
#    (...)
#     387         - state: The final state of the event loop
#     388 """
#     389 events = self.stream_async(prompt, **kwargs)
# --> 390 async for event in events:
#     391     _ = event
#     393 return cast(AgentResult, event["result"])
#
# File /opt/conda/lib/python3.12/site-packages/strands/agent/agent.py:499, in Agent.stream_async(self, prompt, **kwargs)
#     497 try:
#     498     events = self._run_loop(message, invocation_state=kwargs)
# --> 499     async for event in events:
#     500         if "callback" in event:
#     501             callback_handler(**event["callback"])
#
# File /opt/conda/lib/python3.12/site-packages/strands/agent/agent.py:535, in Agent._run_loop(self, message, invocation_state)
#     533     # Execute the event loop cycle with retry logic for context limits
#     534     events = self._execute_event_loop_cycle(invocation_state)
# --> 535     async for event in events:
#     536         yield event
#     538 finally:
#
# File /opt/conda/lib/python3.12/site-packages/strands/agent/agent.py:561, in Agent._execute_event_loop_cycle(self, invocation_state)
#     555 try:
#     556     # Execute the main event loop cycle
#     557     events = event_loop_cycle(
#     558         agent=self,
#     559         invocation_state=invocation_state,
#     560     )
# --> 561     async for event in events:
#     562         yield event
#     564 except ContextWindowOverflowException as e:
#     565     # Try reducing the context size and retrying
#
# File /opt/conda/lib/python3.12/site-packages/strands/event_loop/event_loop.py:182, in event_loop_cycle(agent, invocation_state)
#     180             yield {"callback": {"event_loop_throttled_delay": current_delay, **invocation_state}}
#     181         else:
# --> 182             raise e
#     184 try:
#     185     # Add message in trace and mark the end of the stream messages trace
#     186     stream_trace.add_message(message)
#
# File /opt/conda/lib/python3.12/site-packages/strands/event_loop/event_loop.py:130, in event_loop_cycle(agent, invocation_state)
#     120 agent.hooks.invoke_callbacks(
#     121     BeforeModelInvocationEvent(
#     122         agent=agent,
#     123     )
#     124 )
#     126 try:
#     127     # TODO: To maintain backwards compatibility, we need to combine the stream event with invocation_state
#     128     #       before yielding to the callback handler. This will be revisited when migrating to strongly
#     129     #       typed events.
# --> 130     async for event in stream_messages(agent.model, agent.system_prompt, agent.messages, tool_specs):
#     131         if "callback" in event:
#     132             yield {
#     133                 "callback": {**event["callback"], **(invocation_state if "delta" in event["callback"] else {})}
#     134             }
#
# File /opt/conda/lib/python3.12/site-packages/strands/event_loop/streaming.py:326, in stream_messages(model, system_prompt, messages, tool_specs)
#     322 messages = remove_blank_messages_content_text(messages)
#     324 chunks = model.stream(messages, tool_specs if tool_specs else None, system_prompt)
# --> 326 async for event in process_stream(chunks, messages):
#     327     yield event
#
# File /opt/conda/lib/python3.12/site-packages/strands/event_loop/streaming.py:281, in process_stream(chunks, messages)
#     278 usage: Usage = Usage(inputTokens=0, outputTokens=0, totalTokens=0)
#     279 metrics: Metrics = Metrics(latencyMs=0)
# --> 281 async for chunk in chunks:
#     282     yield {"callback": {"event": chunk}}
#     284     if "messageStart" in chunk:
#
# File /opt/conda/lib/python3.12/site-packages/strands/models/litellm.py:130, in LiteLLMModel.stream(self, messages, tool_specs, system_prompt, **kwargs)
#     127 logger.debug("request=<%s>", request)
#     129 logger.debug("invoking model")
# --> 130 response = await litellm.acompletion(**self.client_args, **request)
#     132 logger.debug("got response from model")
#     133 yield self.format_chunk({"chunk_type": "message_start"})
#
# File /opt/conda/lib/python3.12/site-packages/litellm/utils.py:1495, in client.<locals>.wrapper_async(*args, **kwargs)
#    1493 timeout = _get_wrapper_timeout(kwargs=kwargs, exception=e)
#    1494 setattr(e, "timeout", timeout)
# -> 1495 raise e
#
# File /opt/conda/lib/python3.12/site-packages/litellm/utils.py:1356, in client.<locals>.wrapper_async(*args, **kwargs)
#    1353     return _caching_handler_response.final_embedding_cached_response
#    1355 # MODEL CALL
# -> 1356 result = await original_function(*args, **kwargs)
#    1357 end_time = datetime.datetime.now()
#    1358 if "stream" in kwargs and kwargs["stream"] is True:
#
# File /opt/conda/lib/python3.12/site-packages/litellm/main.py:544, in acompletion(model, messages, functions, function_call, timeout, temperature, top_p, n, stream, stream_options, stop, max_tokens, max_completion_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, parallel_tool_calls, logprobs, top_logprobs, deployment_id, reasoning_effort, base_url, api_version, api_key, model_list, extra_headers, thinking, web_search_options, **kwargs)
#     542 except Exception as e:
#     543     custom_llm_provider = custom_llm_provider or "openai"
# --> 544     raise exception_type(
#     545         model=model,
#     546         custom_llm_provider=custom_llm_provider,
#     547         original_exception=e,
#     548         completion_kwargs=completion_kwargs,
#     549         extra_kwargs=kwargs,
#     550     )
#
# File /opt/conda/lib/python3.12/site-packages/litellm/main.py:517, in acompletion(model, messages, functions, function_call, timeout, temperature, top_p, n, stream, stream_options, stop, max_tokens, max_completion_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, parallel_tool_calls, logprobs, top_logprobs, deployment_id, reasoning_effort, base_url, api_version, api_key, model_list, extra_headers, thinking, web_search_options, **kwargs)
#     514 ctx = contextvars.copy_context()
#     515 func_with_context = partial(ctx.run, func)
# --> 517 init_response = await loop.run_in_executor(None, func_with_context)
#     518 if isinstance(init_response, dict) or isinstance(
#     519     init_response, ModelResponse
#     520 ):  ## CACHING SCENARIO
#     521     if isinstance(init_response, dict):
#
# File /opt/conda/lib/python3.12/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File /opt/conda/lib/python3.12/site-packages/opentelemetry/instrumentation/threading/__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File /opt/conda/lib/python3.12/site-packages/litellm/utils.py:1021, in client.<locals>.wrapper(*args, **kwargs)
#    1018             raise Exception("Max retries per request hit!")
#    1020 # MODEL CALL
# -> 1021 result = original_function(*args, **kwargs)
#    1022 if "stream" in kwargs and kwargs["stream"] is True:
#    1023     if (
#    1024         "complete_response" in kwargs
#    1025         and kwargs["complete_response"] is True
#    1026     ):
#
# File /opt/conda/lib/python3.12/site-packages/litellm/main.py:3305, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3302     return response
#    3303 except Exception as e:
#    3304     ## Map to OpenAI Exception
# -> 3305     raise exception_type(
#    3306         model=model,
#    3307         custom_llm_provider=custom_llm_provider,
#    3308         original_exception=e,
#    3309         completion_kwargs=args,
#    3310         extra_kwargs=kwargs,
#    3311     )
#
# File /opt/conda/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2276, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2274     if isinstance(e, error_type):
#    2275         setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2276         raise e  # it's already mapped
#    2277 raised_exc = APIConnectionError(
#    2278     message="{}\n{}".format(original_exception, traceback.format_exc()),
#    2279     llm_provider="",
#    2280     model="",
#    2281 )
#    2282 setattr(raised_exc, "litellm_response_headers", litellm_response_headers)
#
# File /opt/conda/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2121, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2109             raise APIError(
#    2110                 status_code=original_exception.status_code,
#    2111                 message=f"AzureException APIError - {message}",
#    (...)
#    2117                 ),
#    2118             )
#    2119     else:
#    2120         # if no status code then it is an APIConnectionError: https://github.com/openai/openai-python#handling-errors
# -> 2121         raise APIConnectionError(
#    2122             message=f"{exception_provider} APIConnectionError - {message}\n{traceback.format_exc()}",
#    2123             llm_provider="azure",
#    2124             model=model,
#    2125             litellm_debug_info=extra_information,
#    2126             request=httpx.Request(method="POST", url="https://openai.com/"),
#    2127         )
#    2128 if custom_llm_provider == "openrouter":
#    2129     if hasattr(original_exception, "status_code"):
#
# APIConnectionError: litellm.APIConnectionError: AzureException APIConnectionError - list index out of range
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/litellm/main.py", line 1194, in completion
#     optional_params = get_optional_params(
#                       ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/litellm/utils.py", line 3766, in get_optional_params
#     optional_params = litellm.AzureOpenAIConfig().map_openai_params(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/litellm/llms/azure/chat/gpt_transformation.py", line 165, in map_openai_params
#     api_version_month = api_version_times[1]
#                         ~~~~~~~~~~~~~~~~~^^^
# IndexError: list index out of range

# %% [markdown]
# #### Analysing the agent's results
#
# Nice! We've invoked our agent for the first time! Let's now explore the results object. First thing we can see is the messages being exchanged by the agent in the agent's object

# %%
agent.messages
# Out:
# [{'role': 'user',
#   'content': [{'text': 'What time is it in Seattle? And how is the weather?'}]}]

# %% [markdown]
# Next we can take a look at the usage of our agent for the last query by analysing the result `metrics`

# %%
results.metrics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 results.metrics
#
# NameError: name 'results' is not defined

# %% [markdown]
# ### Congratulations!
#
# In this notebook you learned how to use LiteLLM with OpeanAi serving answers for weather agent.
