# %% [markdown]
# # Building Multi-Agent Systems with Strands Agent Graph
# Multi-agent systems leverage multiple specialized AI agents working together to solve complex problems through coordinated collaboration. Each agent has specific capabilities and roles, connected through explicit communication pathways.
#
# In this lab, you'll learn to build multi-agent systems using the Strands Agent SDK. We'll progress from basic concepts to advanced implementations, exploring different topologies and real-world applications.
#
# **Learning Objectives:**
# By the end of this notebook, you'll be able to:
# - Understand the three core components of agent graphs (nodes, edges, conditions)
# - Send targeted messages between specific agents
# - Monitor and control multi-agent networks
# - Design specialized agent systems for real-world scenarios
#
# ## Prerequisites
#
# - Python 3.10+
# - AWS account with Anthropic Claude 3.7 enabled on Amazon Bedrock
# - IAM role with permissions to use Amazon Bedrock
# - Basic understanding of AI agents and prompt engineering

# %% [markdown]
# ## Setup and Installation
#
# Before we start, let's install the requirement packages for `strands-agents` and `strands-agents-tools`

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.20.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.18)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.12)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.12)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.24.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.46.2)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b1 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.23)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (8.3.1)

# %% [markdown]
# ### Importing required packages
#
# Next we can import the required packages

# %%
from strands import Agent

# %% [markdown]
# ## Understanding Agent Graph Components
# An agent graph is a structured network of interconnected AI agents designed to solve complex problems through coordinated collaboration. Each agent represents a specialized node with specific capabilities, and the connections between agents define explicit communication pathways.
#
# Before we start building, let's understand the three primary components of an agent graph:
#
# ### 1. Nodes (Agents)
# Each node represents an AI agent with:
# - **Identity**: Unique identifier within the graph
# - **Role**: Specialized function or purpose
# - **System Prompt**: Instructions defining the agent's behavior
# - **Tools**: Capabilities available to the agent
#
# ### 2. Edges (Connections)
# Edges define communication pathways with:
# - **Direction**: One-way or bidirectional information flow
# - **Condition**: Optional function that determines if the edge should be traversed
# - **Dependencies**: Define execution order and data flow between nodes
#
# ### 3. GraphBuilder
# The GraphBuilder provides a simple interface for constructing graphs:
# - **add_node()**: Add an agent or multi-agent system as a node
# - **add_edge()**: Create a dependency between nodes
# - **set_entry_point()**: Define starting nodes for execution
# - **build()**: Validate and create the Graph instance

# %% [markdown]
# ### Basic processing
#
# Let's start with a simple example of one task processed by two different agents providing an output that will depend on their defined role. Take a look at the execution order of the nodes and also the fact that with STrands SDK you can explicitly get a response only from one single node if needed. Architecture looks as following:
#
# <div style="text-align:left">
#     <img src="images/basic.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

# Create specialized agents
coordinator = Agent(name="coordinator", system_prompt="You are a research team leader coordinating specialists. Provide a short analysis, no need for follow ups")
analyst = Agent(name="data_analyst", system_prompt="You are a data analyst specializing in statistical analysis. Provide a short analysis, no need for follow ups")
domain_expert = Agent(name="domain_expert", system_prompt="You are a domain expert with deep subject knowledge. Provide a short analysis, no need for follow ups")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(coordinator, "team_lead")
builder.add_node(analyst, "analyst")
builder.add_node(domain_expert, "expert")

# Add edges (dependencies)
builder.add_edge("team_lead", "analyst")
builder.add_edge("team_lead", "expert")

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("team_lead")

# Build the graph
graph = builder.build()

#Execute task on newly built graph
result = graph("Analyze the impact of remote work on employee productivity.Provide a short analysis, no need for follow ups")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes
print("\n")
print("=============Expert node results only:======================")
print("============================================================")
print(result.results["expert"].result)
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ## Remote Work Productivity Impact Analysis
#
# **Key Findings:**
#
# **Positive Impacts:**
# - **Increased flexibility** leads to better work-life balance, reducing burnout and improving focus
# - **Elimination of commute time** adds 1-2 productive hours to employees' days
# - **Reduced workplace distractions** (meetings, interruptions) allows for deeper concentration
# - **Personalized work environments** enable employees to optimize their productivity settings
#
# **Negative Impacts:**
# - **Communication delays** slow down collaborative projects and decision-making
# - **Home distractions** (family, household tasks) can fragment attention
# - **Technology barriers** create inefficiencies for some workers
# - **Isolation effects** may reduce motivation and engagement over time
#
# **Net Assessment:**
# Research indicates a **10-15% overall productivity increase** for remote workers, with significant variation by role type. Knowledge workers and individual contributors see the greatest gains, while collaborative roles face more challenges.
#
# **Critical Success Factors:**
# - Robust digital infrastructure
# - Clear communication protocols
# - Regular check-ins and goal-setting
# - Appropriate home office setup
#
# **Recommendation:** Remote work productivity gains are achievable but require intentional management strategies and individual adaptation support.## Statistical Analysis: Remote Work## Remote Work Productivity Productivity Impact
#
# ** Impact:Data Expert Overview:**
# Base Analysis
#
# Thed on the evidence strongly supports that productivity ** metricsremote work generates presente netd, I productivity gains**, but can provide statistical with context important for the nuances: reporte
#
# **d 10-15% productivityProductivity increase Mechanisms.:**
# - The
#
# **Statistical 10-15% Significance productivity increase:**
# - The stems 10-15% primarily range from **cognitive loa suggestsd reduction** - a ** elimmoderateinating commute stress to, office strong interru positive effectptions, and force** (d synchronCohen's d ization allows≈ deeper 0.5 focus states-0.8
# - **Temporal)
# - This magnitude flexibility** enables workers to of align improvement is stat demandingistically meaningful tasks with their and practically significant peak performance in windows, workplace maxim contextsizing cognitive
# - The range efficiency indicates **vari
# - **Environmental controlability across** reduces different worker sens segmentsory distractions an**,d allows for person whichalized productivity optimization is consistent
#
# **Critical with heterogeneous treatment Moder effectsating Factors:**
#
# **Confidence
# - **Role dependency Assessment is:**
# - crucial**: **High confidence** in Individual positive contributor productivity roles see maximum outcomes benefits for, while coordination knowledge- workers
# - **Mediumintensive confidence** for positions face productivity collaborative friction roles due to offset
# - **Communicationting negative architecture**: factors
# - The **1 As-2 hourynchronous- commfirst communicationute savings models preserve** represents focus while maintaining a meas collaborationurable  effectiveness12
# - **Man-25agerial adaptation% increase**: Productivity in available gains require shifting work from presence time
#
# **Key Statistical-based to outcome- Insights:**
# 1based performance. **Effect management
#
# **Sustainability heter Considerations:**
# Theogeneity** productivity benefits is are ** substantialsustainable long - productivity-term** when organizations gains are invest in proper not uniform infrastructure anly distributed
# 2.d management **Selection practices. However bias, **** likelysocial exists - capital workers eros who thion** canrive remot gradually underely may self-selectmine collaborative into remote arrangements innovation if
# 3. ** not activelyTemporal managed through effects** suggest intent productivityional relationship-building mechanisms gains may diminish over time due to isolation.
#
# **Bottom factors Line:** Remote work productivity gains are real
#
# **Risk and measurable, but Factors:** require organizational
# - Wide design confidence changes to intervals likely fully exist realize. due Companies to role treating-type remote work as simply vari "officeability
# - ** workRegression from to mean home" will** may under occur as novelperty effectsform those wear off
# - Communication who delays coul redesd create **ign workflowsmultiplic forative negative distribute effects** ind effectiveness team.-dependent tasks
#
# **Conclusion:** The 10-15% productivity increase is statistically robust but requires stratified analysis by job function and implementation quality to maintain reliability.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'team_lead': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "## Remote Work Productivity Impact Analysis\n\n**Key Findings:**\n\n**Positive Impacts:**\n- **Increased flexibility** leads to better work-life balance, reducing burnout and improving focus\n- **Elimination of commute time** adds 1-2 productive hours to employees' days\n- **Reduced workplace distractions** (meetings, interruptions) allows for deeper concentration\n- **Personalized work environments** enable employees to optimize their productivity settings\n\n**Negative Impacts:**\n- **Communication delays** slow down collaborative projects and decision-making\n- **Home distractions** (family, household tasks) can fragment attention\n- **Technology barriers** create inefficiencies for some workers\n- **Isolation effects** may reduce motivation and engagement over time\n\n**Net Assessment:**\nResearch indicates a **10-15% overall productivity increase** for remote workers, with significant variation by role type. Knowledge workers and individual contributors see the greatest gains, while collaborative roles face more challenges.\n\n**Critical Success Factors:**\n- Robust digital infrastructure\n- Clear communication protocols\n- Regular check-ins and goal-setting\n- Appropriate home office setup\n\n**Recommendation:** Remote work productivity gains are achievable but require intentional management strategies and individual adaptation support."}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[3.847649335861206], traces=[<strands.telemetry.metrics.Trace object at 0x7fde89f1c290>], accumulated_usage={'inputTokens': 50, 'outputTokens': 271, 'totalTokens': 321}, accumulated_metrics={'latencyMs': 3827}), state={}, interrupts=None, structured_output=None), execution_time=3848, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 50, 'outputTokens': 271, 'totalTokens': 321}, accumulated_metrics={'latencyMs': 3827}, execution_count=1, interrupts=[]), 'expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '## Remote Work Productivity Impact: Expert Analysis\n\nThe evidence strongly supports that **remote work generates net productivity gains**, but with important nuances:\n\n**Productivity Mechanisms:**\n- The 10-15% productivity increase stems primarily from **cognitive load reduction** - eliminating commute stress, office interruptions, and forced synchronization allows deeper focus states\n- **Temporal flexibility** enables workers to align demanding tasks with their peak performance windows, maximizing cognitive efficiency\n- **Environmental control** reduces sensory distractions and allows for personalized productivity optimization\n\n**Critical Moderating Factors:**\n- **Role dependency is crucial**: Individual contributor roles see maximum benefits, while coordination-intensive positions face productivity friction\n- **Communication architecture**: Asynchronous-first communication models preserve focus while maintaining collaboration effectiveness\n- **Managerial adaptation**: Productivity gains require shifting from presence-based to outcome-based performance management\n\n**Sustainability Considerations:**\nThe productivity benefits are **sustainable long-term** when organizations invest in proper infrastructure and management practices. However, **social capital erosion** can gradually undermine collaborative innovation if not actively managed through intentional relationship-building mechanisms.\n\n**Bottom Line:** Remote work productivity gains are real and measurable, but require organizational design changes to fully realize. Companies treating remote work as simply "office work from home" will underperform those who redesign workflows for distributed effectiveness.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, c ...
# =============Node execution order:==========================
# ============================================================
# Executed: team_lead
# Executed: expert
# Executed: analyst
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 3
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 727, 'outputTokens': 904, 'totalTokens': 1631}
#
#
# =============Expert node results only:======================
# ============================================================
# ## Remote Work Productivity Impact: Expert Analysis
#
# The evidence strongly supports that **remote work generates net productivity gains**, but with important nuances:
#
# **Productivity Mechanisms:**
# - The 10-15% productivity increase stems primarily from **cognitive load reduction** - eliminating commute stress, office interruptions, and forced synchronization allows deeper focus states
# - **Temporal flexibility** enables workers to align demanding tasks with their peak performance windows, maximizing cognitive efficiency
# - **Environmental control** reduces sensory distractions and allows for personalized productivity optimization
#
# **Critical Moderating Factors:**
# - **Role dependency is crucial**: Individual contributor roles see maximum benefits, while coordination-intensive positions face productivity friction
# - **Communication architecture**: Asynchronous-first communication models preserve focus while maintaining collaboration effectiveness
# - **Managerial adaptation**: Productivity gains require shifting from presence-based to outcome-based performance management
#
# **Sustainability Considerations:**
# The productivity benefits are **sustainable long-term** when organizations invest in proper infrastructure and management practices. However, **social capital erosion** can gradually undermine collaborative innovation if not actively managed through intentional relationship-building mechanisms.
#
# **Bottom Line:** Remote work productivity gains are real and measurable, but require organizational design changes to fully realize. Companies treating remote work as simply "office work from home" will underperform those who redesign workflows for distributed effectiveness.

# %% [markdown]
# ### Parallel processing
#
# Now let's create a topology when we will have 2 agents processing the request looking at 2 different aspect  of the problem and have them input into a final agent responsible for summarization and risk calculation based on provided input
# <div style="text-align:left">
#     <img src="images/parallel.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

financial_advisor = Agent(name="financial_advisor", system_prompt="You are a financial advisor focused on cost-benefit analysis, budget implications, and ROI calculations. Engage with other experts to build comprehensive financial perspectives.")
technical_architect = Agent(name="technical_architect", system_prompt="You are a technical architect who evaluates feasibility, implementation challenges, and technical risks. Collaborate with other experts to ensure technical viability.")
market_researcher = Agent(name="market_researcher", system_prompt="You are a market researcher who analyzes market conditions, user needs, and competitive landscape. Work with other experts to validate market opportunities.")
risk_analyst = Agent(name="risk_analyst", system_prompt="You are a risk analyst who identifies potential risks, mitigation strategies, and compliance issues. Collaborate with other experts to ensure comprehensive risk assessment.")


# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(financial_advisor, "finance_expert")
builder.add_node(technical_architect, "tech_expert")
builder.add_node(market_researcher, "market_expert")
builder.add_node(risk_analyst, "risk_analyst")

# Add edges (dependencies)
builder.add_edge("finance_expert", "tech_expert")
builder.add_edge("finance_expert", "market_expert")
builder.add_edge("tech_expert", "risk_analyst")
builder.add_edge("market_expert", "risk_analyst")


# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("finance_expert")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Our company is considering launching a new AI-powered customer service platform. Initial investment is \$2M with projected 3-year ROI of 150%. What's your financial assessment?")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes

print("Financial Advisor:")
print("============================================================")
print("============================================================")
print(result.results["finance_expert"].result)
print("\n")

print("Technical Expert:")
print("============================================================")
print("============================================================")
print(result.results["tech_expert"].result)
print("\n")

print("Market Researcher:")
print("============================================================")
print("============================================================")
print(result.results["market_expert"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# Based on the initial data, this appears to be a strong investment opportunity, but I need to dig deeper into the financial structure to provide a comprehensive assessment.
#
# ## Key Financial Metrics Analysis
#
# **ROI Calculation:**
# - 150% ROI over 3 years = $3M total return on $2M investment
# - This translates to approximately 35% annualized return, which is excellent for operational technology investments
#
# ## Critical Questions for Complete Assessment:
#
# **Cash Flow Structure:**
# - What's the projected annual cash flow breakdown? Front-loaded or gradual?
# - When does the platform reach break-even point?
#
# **Cost Structure Deep-dive:**
# - Is the $2M purely development/implementation, or does it include 3-year operational costs?
# - What are ongoing costs (licensing, maintenance, staff training, integration)?
#
# **Revenue Impact Validation:**
# - How was the 150% ROI calculated? Cost savings, revenue increase, or combination?
# - What's the baseline for current customer service costs we're comparing against?
#
# ## Risk Factors to Model:
# - Implementation delays (typical 20-30% in AI projects)
# - Adoption curve assumptions
# - Competitive response impact
# - Technology obsolescence risk
#
# **My recommendation:** The headline numbers look attractive, but I'd want to see a detailed NPV analysis with sensitivity testing on key assumptions before final approval.
#
# What's your timeline for implementation, and do you have comparable industry benchmarks for similar AI customer service ROI?# Market Research Analysis: AI-Powered Customer Service Platform
#
# Building on the finance expert's insights, I'll provide crucial market validation to support this investment decision.
#
# ## Market Opportunity Assessment
#
# **Market Size & Growth:**
# - Global AI customer service market: $4.2B (2023) → projecte#d $15 Technical.7B by 2028  Architecture(30. Assessment: AI-Powered Customer Service1 Platform
#
# ## Technical% CAGR)
# - Enterprise Feasibility Analysis
#
# ** segmentCore Architecture Vi specifically growingability: at 35% HIGH+ annually
# - **73% of companies
# The propose plan to increase AI customerd AI service investment in next customer 2 years service platform is
#
# ## technically sound and al Competitive Landscape Realityigns with proven Check
#
# **Market Sat enterpriseuration Analysis architect:**
# - 200ures. However+ players in this, several space, including major critical technical incumbents (Sales factorsforce, Microsoft, coul Zendesk)
# - **Criticald significantly Gap impact the:** Mi financiald-market segment (100-1000 proj employees) underections.served by current solutions
# -
#
# ## Different Implementationiation will be key Complexity & - generic Timeline platforms struggling to achieve Risks projected ROIs
#
# ## User
#
# **Development Need Validation
#
# ** TimelineCustomer Pain Reality Points ( Checkfrom recent:**
# - **Minimum surveys):**
# - viable 68 platform% report current**: 8 AI solutions-12 months ( lack contextnotual understanding
# - 45 6% cite integration complexity as primary barrier months often
# - Average assume implementationd)
# - **Full time: 8-12 months feature ( deploymentsupports finance**: 12-18 months
# - **Enterprise expert's delay risk concerns integration)
#
# ****: AdditionalROI Benchmark  Reality3:**-6 months
# - Industry average AI
#
# ⚠️ **Critical Risk**: customer service ROI:  85-12065% over 3% of years
# - Top quart AI customerile performers service projects experience: 140-180 %6
# - **+ month delays, directlyYour 150% projection sits impacting ROI timeline in an realistic range butd cash flow proj requiresections.
#
# ## Technical strong execution Cost**
#
# ## Market Implications Entry
#
# **Infrastructure Timing Requirements Beyon
#
# **Favorable factorsd Initial:**
# - Post $-pandemic customer service transformation still2M:**
# - **Clou underway
# - Labord infrastructure scaling shortage driving AI adoption acceleration**: $200
#
# **RiskK-500 factors:**
# - Market becomingK annually crow (ded - firstdepends on volume-mover advantage dimin)
# - **AIishing
# - Potential economic model training/ downturn coulred delaytraining**: $150 enterprise AIK-300K annually spending
#
# ## Recommendation
# - **Security
#
# The & market compliance tools opportunity validates the financial**: $100K-200K annually proj
# - **Integrationections **IF middleware** you**: $75 have:
# 1. ClearK-150K up differentfront
#
# ## Keyiation strategy Technical Risks
# 2. Proven implementation methodology
# 3. Strong Affecting integration capabilities ROI
#
# **High-Impact
#
# **Key validation Risks:**
# 1. **Data neede Quality Issues**d:** (40% probability Customer discovery interviews with): 10 Poor-15 target prospects to confirm will historicalingness to pay an customerd adoption timeline assumptions data coul used delayd in your ROI calculations deployment.
#
# What's  your unique3 value proposition versus existing solutions?-6 months
# 2. **Legacy System Integration** (60% probability): Complex integrations often double implementation time
# 3. **AI Model Performance** (30% probability): Underperforming models require expensive retraining cycles
#
# **Medium-Impact Risks:**
# - Scalability bottlenecks during peak usage
# - Compliance challenges (GDPR, industry regulations)
# - Staff training curve steeper than anticipated
#
# ## Technical Requirements for Success
#
# **Critical Success Factors:**
# - Robust API layer for seamless integrations
# - Real-time model monitoring and auto-scaling
# - Comprehensive data governance framework
# - Fallback systems for AI model failures
#
# ## Recommendation to Finance Team
#
# The technical architecture is sound, but I recommend **adjusting financial projections**:
# - Extend implementation timeline by 25-35%
# - Add 15-20% contingency for technical integration costs
# - Include annual operational infrastructure costs in ROI calculations
#
# The 150% ROI remains achievable but likely over 4 years rather than 3, which significantly impacts NPV calculations.
#
# **Next Steps**: Conduct detailed technical due diligence on existing system architecture and data readiness before finalizing investment timeline.# Risk Analysis: AI-Powered Customer Service Platform Investment
#
# ## Executive Risk Summary
# While the $2M investment shows promise with a 150% ROI projection, **multiple high-impact risks could significantly erode returns**. The technical and market assessments reveal critical vulnerabilities that require immediate mitigation strategies.
#
# ## Critical Risk Categories
#
# ### 1. **EXECUTION RISKS (HIGH IMPACT)**
#
# **Timeline Risk - 70% Probability**
# - Tech expert confirms 65% of projects experience 6+ month delays
# - **Financial Impact**: Delayed revenue recognition could reduce 3-year ROI from 150% to 95-110%
# - **Mitigation**: Build 35% timeline buffer; establish milestone-based budget releases
#
# **Integration Complexity Risk - 60% Probability**
# - Legacy system integration challenges could double implementation costs
# - **Financial Impact**: Additional $300K-600K in unforeseen integration expenses
# - **Mitigation**: Conduct thorough technical due diligence; pre-contract with integration specialists
#
# ### 2. **MARKET RISKS (MEDIUM-HIGH IMPACT)**
#
# **Competitive Displacement Risk - 45% Probability**
# - 200+ competitors in increasingly saturated market
# - Major players (Salesforce, Microsoft) have pricing/resource advantages
# - **Financial Impact**: Could limit market penetration by 40-60%
# - **Mitigation**: Develop unique IP; target underserved mid-market niche identified by market expert
#
# **Economic Downturn Risk - 35% Probability**
# - Enterprise AI spending vulnerable to economic cycles
# - **Financial Impact**: 6-12 month sales cycle delays; 20-30% revenue reduction
# - **Mitigation**: Diversify customer base; develop recession-resilient pricing models
#
# ### 3. **OPERATIONAL RISKS (MEDIUM IMPACT)**
#
# **AI Model Performance Risk - 30% Probability**
# - Underperforming models require expensive retraining cycles
# - **Financial Impact**: $150K-300K annually in additional costs
# - **Mitigation**: Establish performance benchmarks; budget for continuous model improvement
#
# **Data Quality Risk - 40% Probability**
# - Poor customer data could delay deployment significantly
# - **Financial Impact**: 3-6 month revenue delays
# - **Mitigation**: Data audit before full investment; phased rollout approach
#
# ### 4. **COMPLIANCE & REGULATORY RISKS (MEDIUM IMPACT)**
#
# **Data Privacy Compliance - 25% Probability**
# - GDPR, CCPA, industry-specific regulations
# - **Financial Impact**: $100K-500K in compliance costs; potential fines
# - **Mitigation**: Engage compliance experts early; build privacy-by-design architecture
#
# ## Financial Risk Adjustments
#
# **Revised ROI Projections:**
# - **Base Case**: 120-130% (vs. projected 150%)
# - **Worst Case**: 65-85%
# - **Best Case**: 140-160%
#
# **Additional Budget Requirements:**
# - **Risk Contingency**: $400K-600K (20-30% of initial investment)
# - **Annual Operational Buffer**: $200K for unforeseen costs
#
# ## Risk Mitigation Strategy
#
# ### Phase 1: Pre-Investment (Next 60 days)
# 1. **Technical Due Diligence**: Assess existing systems integration complexity
# 2. **Market Validation**: Interview 15+ target customers for willingness-to-pay confirmation
# 3. **Legal/Compliance Review**: Map regulatory requirements early
#
# ### Phase 2: Implementation Risk Controls
# 1. **Milestone-Based Funding**: Release funds tied to specific deliverables
# 2. **Performance Monitoring**: Real-time dashboard for key risk indicators
# 3. **Vendor Management**: Pre-negotiated contracts with backup integration partners
#
# ## Final Risk Assessment
#
# **Investment Recommendation**: **PROCEED WITH CAUTION**
#
# The opportunity is viable but requires:
# - **Reduced ROI expectations** (120-130% vs 150%)
# - **Extended timeline** (4 years vs 3 years)
# - **Increased total investment** ($2.4M-2.6M vs $2M)
#
# **Go/No-Go Criteria:**
# ✅ Proceed IF: Market validation interviews confirm demand + technical audit shows manageable integration complexity
# ❌ Halt IF: Customer interviews show price resistance + technical audit reveals major integration barriers
#
# **Next Critical Step**: Complete risk mitigation Phase 1 activities before final investment approval.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'finance_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "Based on the initial data, this appears to be a strong investment opportunity, but I need to dig deeper into the financial structure to provide a comprehensive assessment.\n\n## Key Financial Metrics Analysis\n\n**ROI Calculation:**\n- 150% ROI over 3 years = $3M total return on $2M investment\n- This translates to approximately 35% annualized return, which is excellent for operational technology investments\n\n## Critical Questions for Complete Assessment:\n\n**Cash Flow Structure:**\n- What's the projected annual cash flow breakdown? Front-loaded or gradual?\n- When does the platform reach break-even point?\n\n**Cost Structure Deep-dive:**\n- Is the $2M purely development/implementation, or does it include 3-year operational costs?\n- What are ongoing costs (licensing, maintenance, staff training, integration)?\n\n**Revenue Impact Validation:**\n- How was the 150% ROI calculated? Cost savings, revenue increase, or combination?\n- What's the baseline for current customer service costs we're comparing against?\n\n## Risk Factors to Model:\n- Implementation delays (typical 20-30% in AI projects)\n- Adoption curve assumptions\n- Competitive response impact\n- Technology obsolescence risk\n\n**My recommendation:** The headline numbers look attractive, but I'd want to see a detailed NPV analysis with sensitivity testing on key assumptions before final approval. \n\nWhat's your timeline for implementation, and do you have comparable industry benchmarks for similar AI customer service ROI?"}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[5.185718536376953], traces=[<strands.telemetry.metrics.Trace object at 0x7fde5e9f79b0>], accumulated_usage={'inputTokens': 77, 'outputTokens': 326, 'totalTokens': 403}, accumulated_metrics={'latencyMs': 5166}), state={}, interrupts=None, structured_output=None), execution_time=5186, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 77, 'outputTokens': 326, 'totalTokens': 403}, accumulated_metrics={'latencyMs': 5166}, execution_count=1, interrupts=[]), 'market_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Market Research Analysis: AI-Powered Customer Service Platform\n\nBuilding on the finance expert's insights, I'll provide crucial market validation to support this investment decision.\n\n## Market Opportunity Assessment\n\n**Market Size & Growth:**\n- Global AI customer service market: $4.2B (2023) → projected $15.7B by 2028 (30.1% CAGR)\n- Enterprise segment specifically growing at 35%+ annually\n- 73% of companies plan to increase AI customer service investment in next 2 years\n\n## Competitive Landscape Reality Check\n\n**Market Saturation Analysis:**\n- 200+ players in this space, including major incumbents (Salesforce, Microsoft, Zendesk)\n- **Critical Gap:** Mid-market segment (100-1000 employees) underserved by current solutions\n- Differentiation will be key - generic platforms struggling to achieve projected ROIs\n\n## User Need Validation\n\n**Customer Pain Points (from recent surveys):**\n- 68% report current AI solutions lack contextual understanding\n- 45% cite integration complexity as primary barrier\n- Average implementation time: 8-12 months (supports finance expert's delay risk concerns)\n\n**ROI Benchmark Reality:**\n- Industry average AI customer service ROI: 85-120% over 3 years\n- Top quartile performers: 140-180%\n- **Your 150% projection sits in realistic range but requires strong execution**\n\n## Market Entry Timing\n\n**Favorable factors:**\n- Post-pandemic customer service transformation still underway\n- Labor shortage driving AI adoption acceleration\n\n**Risk factors:**\n- Market becoming crowded - first-mover advantage diminishing\n- Potential economic  ...
# =============Node execution order:==========================
# ============================================================
# Executed: finance_expert
# Executed: market_expert
# Executed: tech_expert
# Executed: risk_analyst
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 4
# Completed nodes: 4
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 2029, 'outputTokens': 2354, 'totalTokens': 4383}
# Financial Advisor:
# ============================================================
# ============================================================
# Based on the initial data, this appears to be a strong investment opportunity, but I need to dig deeper into the financial structure to provide a comprehensive assessment.
#
# ## Key Financial Metrics Analysis
#
# **ROI Calculation:**
# - 150% ROI over 3 years = $3M total return on $2M investment
# - This translates to approximately 35% annualized return, which is excellent for operational technology investments
#
# ## Critical Questions for Complete Assessment:
#
# **Cash Flow Structure:**
# - What's the projected annual cash flow breakdown? Front-loaded or gradual?
# - When does the platform reach break-even point?
#
# **Cost Structure Deep-dive:**
# - Is the $2M purely development/implementation, or does it include 3-year operational costs?
# - What are ongoing costs (licensing, maintenance, staff training, integration)?
#
# **Revenue Impact Validation:**
# - How was the 150% ROI calculated? Cost savings, revenue increase, or combination?
# - What's the baseline for current customer service costs we're comparing against?
#
# ## Risk Factors to Model:
# - Implementation delays (typical 20-30% in AI projects)
# - Adoption curve assumptions
# - Competitive response impact
# - Technology obsolescence risk
#
# **My recommendation:** The headline numbers look attractive, but I'd want to see a detailed NPV analysis with sensitivity testing on key assumptions before final approval.
#
# What's your timeline for implementation, and do you have comparable industry benchmarks for similar AI customer service ROI?
#
#
#
# Technical Expert:
# ============================================================
# ============================================================
# # Technical Architecture Assessment: AI-Powered Customer Service Platform
#
# ## Technical Feasibility Analysis
#
# **Core Architecture Viability: HIGH**
# The proposed AI customer service platform is technically sound and aligns with proven enterprise architectures. However, several critical technical factors could significantly impact the financial projections.
#
# ## Implementation Complexity & Timeline Risks
#
# **Development Timeline Reality Check:**
# - **Minimum viable platform**: 8-12 months (not 6 months often assumed)
# - **Full feature deployment**: 12-18 months
# - **Enterprise integration**: Additional 3-6 months
#
# ⚠️ **Critical Risk**: 65% of AI customer service projects experience 6+ month delays, directly impacting ROI timeline and cash flow projections.
#
# ## Technical Cost Implications
#
# **Infrastructure Requirements Beyond Initial $2M:**
# - **Cloud infrastructure scaling**: $200K-500K annually (depends on volume)
# - **AI model training/retraining**: $150K-300K annually
# - **Security & compliance tools**: $100K-200K annually
# - **Integration middleware**: $75K-150K upfront
#
# ## Key Technical Risks Affecting ROI
#
# **High-Impact Risks:**
# 1. **Data Quality Issues** (40% probability): Poor historical customer data could delay deployment 3-6 months
# 2. **Legacy System Integration** (60% probability): Complex integrations often double implementation time
# 3. **AI Model Performance** (30% probability): Underperforming models require expensive retraining cycles
#
# **Medium-Impact Risks:**
# - Scalability bottlenecks during peak usage
# - Compliance challenges (GDPR, industry regulations)
# - Staff training curve steeper than anticipated
#
# ## Technical Requirements for Success
#
# **Critical Success Factors:**
# - Robust API layer for seamless integrations
# - Real-time model monitoring and auto-scaling
# - Comprehensive data governance framework
# - Fallback systems for AI model failures
#
# ## Recommendation to Finance Team
#
# The technical architecture is sound, but I recommend **adjusting financial projections**:
# - Extend implementation timeline by 25-35%
# - Add 15-20% contingency for technical integration costs
# - Include annual operational infrastructure costs in ROI calculations
#
# The 150% ROI remains achievable but likely over 4 years rather than 3, which significantly impacts NPV calculations.
#
# **Next Steps**: Conduct detailed technical due diligence on existing system architecture and data readiness before finalizing investment timeline.
#
#
#
# Market Researcher:
# ============================================================
# ============================================================
# # Market Research Analysis: AI-Powered Customer Service Platform
#
# Building on the finance expert's insights, I'll provide crucial market validation to support this investment decision.
#
# ## Market Opportunity Assessment
#
# **Market Size & Growth:**
# - Global AI customer service market: $4.2B (2023) → projected $15.7B by 2028 (30.1% CAGR)
# - Enterprise segment specifically growing at 35%+ annually
# - 73% of companies plan to increase AI customer service investment in next 2 years
#
# ## Competitive Landscape Reality Check
#
# **Market Saturation Analysis:**
# - 200+ players in this space, including major incumbents (Salesforce, Microsoft, Zendesk)
# - **Critical Gap:** Mid-market segment (100-1000 employees) underserved by current solutions
# - Differentiation will be key - generic platforms struggling to achieve projected ROIs
#
# ## User Need Validation
#
# **Customer Pain Points (from recent surveys):**
# - 68% report current AI solutions lack contextual understanding
# - 45% cite integration complexity as primary barrier
# - Average implementation time: 8-12 months (supports finance expert's delay risk concerns)
#
# **ROI Benchmark Reality:**
# - Industry average AI customer service ROI: 85-120% over 3 years
# - Top quartile performers: 140-180%
# - **Your 150% projection sits in realistic range but requires strong execution**
#
# ## Market Entry Timing
#
# **Favorable factors:**
# - Post-pandemic customer service transformation still underway
# - Labor shortage driving AI adoption acceleration
#
# **Risk factors:**
# - Market becoming crowded - first-mover advantage diminishing
# - Potential economic downturn could delay enterprise AI spending
#
# ## Recommendation
#
# The market opportunity validates the financial projections **IF** you have:
# 1. Clear differentiation strategy
# 2. Proven implementation methodology
# 3. Strong integration capabilities
#
# **Key validation needed:** Customer discovery interviews with 10-15 target prospects to confirm willingness to pay and adoption timeline assumptions used in your ROI calculations.
#
# What's your unique value proposition versus existing solutions?

# %% [markdown]
# ### Branching with conditions
#
# Let's create an agent graph that would classify the request and depending on conditions we define in the code - will route the request either to technical or business agent.
#
# Take a close look on differences between the node execution order and number of nodes executed in this graph based on two different prompts.
#
# <div style="text-align:left">
#     <img src="images/conditional.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

classifier = Agent(name="classifier", system_prompt="You are an agent responsible for classification of the report request, return only Technical or Business clasification.")
technical_report = Agent(name="technical_expert", system_prompt="You are a technical expert htat focuses on providing short summary from technical perspective")
business_report = Agent(name="business_expert", system_prompt="You are a business expert that focuses on providing short summary from business perspective")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(classifier, "classifier")
builder.add_node(technical_report, "technical_report")
builder.add_node(business_report, "business_report")

def is_technical(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "technical" in result_text.lower()

def is_business(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "business" in result_text.lower()

# Add edges (dependencies)
builder.add_edge("classifier", "technical_report", condition=is_technical)
builder.add_edge("classifier", "business_report", condition=is_business)

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("classifier")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Provide report on technical aspect of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")

#Execute task on newly built graph
result = graph("Provide report on business impact of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# Technical# Technical Aspects of Working From Home: Key Considerations and Risk Factors
#
# ## Core Technical Requirements
#
# **Essential Infrastructure:**
# - Reliable high-speed internet (minimum 25 Mbps download, 10 Mbps upload)
# - Backup connectivity solutions (mobile hotspot, secondary ISP)
# - Adequate hardware: laptop/desktop with sufficient RAM (8GB+) and processing power
# - Proper display setup and ergonomic peripherals
#
# ## Security Risk Factors
#
# **Network Vulnerabilities:**
# - Unsecured home Wi-Fi networks
# - Shared network access with family devices
# - Lack of enterprise-grade firewall protection
#
# **Data Protection Concerns:**
# - Inadequate endpoint security
# - Unencrypted data transmission
# - Physical security of devices and documents
# - BYOD policy compliance gaps
#
# ## Technical Challenges
#
# **Connectivity Issues:**
# - Internet service reliability and bandwidth limitations
# - VPN performance degradation
# - Latency impacts on real-time collaboration
#
# **IT Support Limitations:**
# - Remote troubleshooting complexity
# - Hardware replacement delays
# - Software licensing and deployment challenges
#
# ## Key Recommendations
#
# 1. **Implement robust VPN solutions** with split-tunneling capabilities
# 2. **Deploy endpoint detection and response (EDR)** tools
# 3. **Establish secure cloud storage** with proper access controls
# 4. **Create standardized home office technical specifications**
# 5. **Develop remote IT support protocols** and self-service resources
#
# Regular security assessments and technical audits are essential for maintaining operational integrity.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'classifier': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Technical'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.6902649402618408], traces=[<strands.telemetry.metrics.Trace object at 0x7fde5a9d73b0>], accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 1671}), state={}, interrupts=None, structured_output=None), execution_time=1691, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 1671}, execution_count=1, interrupts=[]), 'technical_report': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Technical Aspects of Working From Home: Key Considerations and Risk Factors\n\n## Core Technical Requirements\n\n**Essential Infrastructure:**\n- Reliable high-speed internet (minimum 25 Mbps download, 10 Mbps upload)\n- Backup connectivity solutions (mobile hotspot, secondary ISP)\n- Adequate hardware: laptop/desktop with sufficient RAM (8GB+) and processing power\n- Proper display setup and ergonomic peripherals\n\n## Security Risk Factors\n\n**Network Vulnerabilities:**\n- Unsecured home Wi-Fi networks\n- Shared network access with family devices\n- Lack of enterprise-grade firewall protection\n\n**Data Protection Concerns:**\n- Inadequate endpoint security\n- Unencrypted data transmission\n- Physical security of devices and documents\n- BYOD policy compliance gaps\n\n## Technical Challenges\n\n**Connectivity Issues:**\n- Internet service reliability and bandwidth limitations\n- VPN performance degradation\n- Latency impacts on real-time collaboration\n\n**IT Support Limitations:**\n- Remote troubleshooting complexity\n- Hardware replacement delays\n- Software licensing and deployment challenges\n\n## Key Recommendations\n\n1. **Implement robust VPN solutions** with split-tunneling capabilities\n2. **Deploy endpoint detection and response (EDR)** tools\n3. **Establish secure cloud storage** with proper access controls\n4. **Create standardized home office technical specifications**\n5. **Develop remote IT support protocols** and self-service resources\n\nRegular security assessments and technical audits are essential for maintaining operational integrity.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[7.838696002960205], traces=[<strands.telemetry.metrics.Trace object at 0x7fde5a9d7500>], accumulated_usage={'inputTokens': 60, 'outputTokens': 344, 'totalTokens': 404}, accumulated_metrics={'latencyMs': 7820}), state={}, interrupts=None, structured_output=None), execution_time=7839, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 60, 'outputTokens': 344, 'totalTokens': 404}, accumulated_metrics={'latencyMs': 7820}, execution_count=1, interrupts=[])}, accumulated_usage={'inputTokens': 106, 'outputTokens': 348, 'totalTokens': 454}, accumulated_metrics={'latencyMs': 9491}, execution_count=2, execution_time=0, interrupts=[], total_nodes=3, completed_nodes=2, failed_nodes=0, execution_order=[GraphNode(node_id='classifier', executor=<strands.agent.agent.Agent object at 0x7fde5c10e3f0>, dependencies=set(), execution_status=<Status.COMPLETED: 'completed'>, result=NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Technical'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.6902649402618408], traces=[<strands.telemetry.metrics.Trace object at 0x7fde5a9d73b0>], accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 1671}), state={}, interrupts=None, structured_output=None), execution_time=1691, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 46, 'out ...
# =============Node execution order:==========================
# ============================================================
# Executed: classifier
# Executed: technical_report
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 2
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 106, 'outputTokens': 348, 'totalTokens': 454}
# Classifier:
# ============================================================
# ============================================================
# Technical
#
#
#
# Business# Business Impact of Working From Home: Executive Summary
#
# ## Key Business Impacts
#
# **Positive Impacts:**
# - **Cost Reduction**: 25-30% savings on office space, utilities, and facilities
# - **Talent Access**: Expanded recruitment pool beyond geographical constraints
# - **Productivity Gains**: 13-50% increase reported by companies like Microsoft and Shopify
# - **Employee Retention**: 54% reduction in turnover rates for remote-friendly companies
#
# **Negative Impacts:**
# - **Collaboration Challenges**: 67% of executives report decreased spontaneous innovation
# - **Management Complexity**: Increased oversight and communication coordination costs
# - **Technology Infrastructure**: 15-20% increase in IT spending per employee
#
# ## Critical Considerations
#
# 1. **Role Suitability**: Customer service, software development, and knowledge work adapt well; manufacturing, healthcare, and retail face significant limitations
#
# 2. **Hybrid Models**: 83% of companies adopting flexible arrangements rather than full remote
#
# 3. **Performance Metrics**: Shift from hours-worked to outcomes-based measurement systems
#
# 4. **Company Culture**: Requires intentional investment in virtual team building and communication protocols
#
# ## Key Risk Factors
#
# - **Cybersecurity**: 300% increase in cyberattacks on remote workers
# - **Compliance**: Regulatory challenges across multiple jurisdictions
# - **Employee Burnout**: 38% report longer working hours from home
# - **Skills Gap**: Management capabilities for remote teams often underdeveloped
#
# ## Recommendation
# Implement structured hybrid approach with clear policies, technology investment, and performance frameworks to maximize benefits while mitigating risks.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'classifier': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Business'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[1.6902649402618408, 0.7436788082122803], traces=[<strands.telemetry.metrics.Trace object at 0x7fde5a9d73b0>, <strands.telemetry.metrics.Trace object at 0x7fde5a9d7800>], accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 2410}), state={}, interrupts=None, structured_output=None), execution_time=744, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 2410}, execution_count=1, interrupts=[]), 'business_report': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Business Impact of Working From Home: Executive Summary\n\n## Key Business Impacts\n\n**Positive Impacts:**\n- **Cost Reduction**: 25-30% savings on office space, utilities, and facilities\n- **Talent Access**: Expanded recruitment pool beyond geographical constraints\n- **Productivity Gains**: 13-50% increase reported by companies like Microsoft and Shopify\n- **Employee Retention**: 54% reduction in turnover rates for remote-friendly companies\n\n**Negative Impacts:**\n- **Collaboration Challenges**: 67% of executives report decreased spontaneous innovation\n- **Management Complexity**: Increased oversight and communication coordination costs\n- **Technology Infrastructure**: 15-20% increase in IT spending per employee\n\n## Critical Considerations\n\n1. **Role Suitability**: Customer service, software development, and knowledge work adapt well; manufacturing, healthcare, and retail face significant limitations\n\n2. **Hybrid Models**: 83% of companies adopting flexible arrangements rather than full remote\n\n3. **Performance Metrics**: Shift from hours-worked to outcomes-based measurement systems\n\n4. **Company Culture**: Requires intentional investment in virtual team building and communication protocols\n\n## Key Risk Factors\n\n- **Cybersecurity**: 300% increase in cyberattacks on remote workers\n- **Compliance**: Regulatory challenges across multiple jurisdictions\n- **Employee Burnout**: 38% report longer working hours from home\n- **Skills Gap**: Management capabilities for remote teams often underdeveloped\n\n## Recommendation\nImplement structured hybrid approach with clear policies, technology investment, and performance frameworks to maximize benefits while mitigating risks.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[8.152589321136475], traces=[<strands.telemetry.metrics.Trace object at 0x7fde5a9d7650>], accumulated_usage={'inputTokens': 59, 'outputTokens': 357, 'totalTokens': 416}, accumulated_metrics={'latencyMs': 8129}), state={}, interrupts=None, structured_output=None), execution_time=8153, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 59, 'outputTokens': 357, 'totalTokens': 416}, accumulated_metrics={'latencyMs': 8129}, execution_count=1, interrupts=[])}, accumulated_usage={'inputTokens': 177, 'outputTokens': 365, 'totalTokens': 542}, accumulated_metrics={'latencyMs': 10539}, execution_count=2, execution_time=0, interrupts=[], total_nodes=3, completed_nodes=2, failed_nodes=0, execution_order=[GraphNode(node_id='classifier', executor=<strands.agent.agent.Agent object at 0x7fde5c10e3f0>, dependencies=set(), execution_status=<Status.COMPLETED: 'completed'>, result=NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Business'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[1.6902649402618408, 0.7436788082122803], traces=[<strands.telemetry.metrics.Trace object at 0x7fde5a9d73b0>, <strands.telemetry.metrics.Trace object a ...
# =============Node execution order:==========================
# ============================================================
# Executed: classifier
# Executed: business_report
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 2
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 177, 'outputTokens': 365, 'totalTokens': 542}
# Classifier:
# ============================================================
# ============================================================
# Business

# %% [markdown]
# ## Key Takeaways and Best Practices
#
#
# ### Best Practices:
#
# **Design for acyclicity:** Ensure your graph has no cycles</p>
# **Use meaningful node IDs:** Choose descriptive names for nodes</p>
# **Validate graph structure:** The builder will check for cycles and validate entry points</p>
# **Handle node failures:** Consider how failures in one node affect the overall workflow</p>
# **Use conditional edges:** For dynamic workflows based on intermediate results</p>
# **Consider parallelism:** Independent branches can execute concurrently</p>
# **Nest multi-agent patterns:** Use Swarms within Graphs for complex workflows</p>
# **Leverage multi-modal inputs:** Use ContentBlocks for rich inputs including images</p>
#
# ## Conclusion
#
# You've now mastered the fundamentals of building multi-agent systems with Strands Agent Graph! You can create sophisticated networks of specialized AI agents that collaborate to solve complex problems.
#
# The key to successful multi-agent systems is:
# - Matching topology to use case
# - Defining clear agent roles and responsibilities
# - Establishing proper communication patterns
# - Managing resources and cleanup effectively
#
# From here, you can build increasingly sophisticated systems for real-world applications in research, content creation, decision-making, customer service, and beyond.
